# %%
import requests
from bs4 import BeautifulSoup as bs
from requests_html import HTMLSession

# %%
authorsURL = "https://suw.biblos.pk.edu.pl/browseByAuthor"
content = requests.get(authorsURL)

# %%
# URL = "https://suw.biblos.pk.edu.pl/ajax_displaySearchResults&sId=16453"

# "https://suw.biblos.pk.edu.pl/browseByAuthor"
# get authors, in href there is uId

print(bs(content.text).prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html>
# <head>
# <title>Bibliografia Publikacji Pracowników PK. Przeglądanie według autorów</title>
# <meta content="RevealTrans(duration=0,transition=5)" http-equiv="Page-Enter"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="SUW - Zintegrowany System Wymiany Wiedzy i Udostępniania Akademickich Publikacji z Zakresu Nauk Technicznych" name="keywords"/>
# <meta content="Bibliotek Politechniki Krakowskiej. Zintegrowany System Wymiany Wiedzy i Udostępniania Akademickich Publikacji z Zakresu Nauk Technicznych" name="description"/>
# <link href="/suw/link/suw.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico" rel="icon" type="image/ico"/>
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# ...

# %%
# "https://suw.biblos.pk.edu.pl/userHomepage&uId=927&rel=BPP-author"
# publicies by author
# find sId=16453-927 for author and then 
# https://suw.biblos.pk.edu.pl/ajax_displaySearchResults&sId=16453-927&rsAt=0
#
